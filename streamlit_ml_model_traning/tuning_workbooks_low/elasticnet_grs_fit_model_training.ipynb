# %%
from os.path import join, dirname
from dotenv import load_dotenv
import os
import pickle
from snowflake import connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter, StrMethodFormatter
from scipy.optimize import curve_fit
from sklearn.preprocessing import Normalizer, QuantileTransformer, RobustScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, mean_absolute_percentage_error, median_absolute_error, max_error, make_scorer


pd.options.display.float_format = '{:,.2f}'.format

# get environment variables
dotenv_path = join(dirname('streamlit_grs_fit\\app\\'), '.env')
load_dotenv(dotenv_path)
SF_ACCOUNT = os.getenv('SF_ACCOUNT')
SF_USER = os.getenv('SF_USER')
SF_PASSWORD = os.getenv('SF_PASSWORD')
SF_ROLE = os.getenv('SF_ROLE')
SF_WAREHOUSE = os.getenv('SF_WAREHOUSE')
SF_DATABASE = os.getenv('SF_DATABASE')
SF_SCHEMA = os.getenv('SF_SCHEMA')

def load_data(query):
    conn = connector.connect(
        user = SF_USER
        ,password = SF_PASSWORD
        ,account = SF_ACCOUNT
        ,warehouse = SF_WAREHOUSE
        ,database = SF_DATABASE
        ,schema = SF_SCHEMA
        ,role = SF_ROLE
    )
    cur = conn.cursor()
    df_data = cur.execute(query).fetch_pandas_all()
    return df_data

# %%
query = 'select '+\
            'JOB'+\
            ',DIRECT_COST'+\
            ',DIV_00_DIRECT_COST'+\
            ',DIV_01_DIRECT_COST'+\
            ',DIV_02_DIRECT_COST'+\
            ',DIV_03_DIRECT_COST'+\
            ',DIV_04_DIRECT_COST'+\
            ',DIV_05_DIRECT_COST'+\
            ',DIV_06_DIRECT_COST'+\
            ',DIV_07_DIRECT_COST'+\
            ',DIV_08_DIRECT_COST'+\
            ',DIV_09_DIRECT_COST'+\
            ',DIV_10_DIRECT_COST'+\
            ',DIV_11_DIRECT_COST'+\
            ',DIV_12_DIRECT_COST'+\
            ',DIV_13_DIRECT_COST'+\
            ',DIV_14_DIRECT_COST'+\
            ',DIV_15_DIRECT_COST'+\
            ',DIV_16_DIRECT_COST'+\
            ',DIV_17_DIRECT_COST'+\
            ',DIV_18_DIRECT_COST'+\
            ',DIV_19_DIRECT_COST'+\
            ',DIV_21_DIRECT_COST'+\
            ',DIV_22_DIRECT_COST'+\
            ',DIV_23_DIRECT_COST'+\
            ',DIV_26_DIRECT_COST'+\
            ',DIV_27_DIRECT_COST'+\
            ',DIV_28_DIRECT_COST'+\
            ',DIV_31_DIRECT_COST'+\
            ',DIV_32_DIRECT_COST'+\
            ',DIV_33_DIRECT_COST'+\
            ',DIV_34_DIRECT_COST'+\
            ',DIV_55_DIRECT_COST'+\
            ',GCS_COST'+\
            ',GRS_COST '+\
            'from sandbox.global.ml_grs_fit ' 
df_data = load_data(query).set_index('JOB') 
df_data = pd.DataFrame(df_data)
df_data = df_data.fillna(0)

# %%
df_working = df_data.loc[
                    (0 != df_data.GRS_COST) &
                    (0 != df_data.GCS_COST)
].copy()
df_working.describe()
# Out:
#          DIRECT_COST  DIV_00_DIRECT_COST  DIV_01_DIRECT_COST  \
# count       3,332.00            3,332.00            3,332.00
# mean    2,753,305.18           15,416.14            1,095.30
# std    18,205,353.59          247,803.94           21,856.71
# min    -3,404,153.00         -327,264.32                0.00
# 25%         4,410.75                0.00                0.00
# 50%        31,937.00                0.00                0.00
# 75%       279,720.25                0.00                0.00
# max   399,570,438.00        8,618,727.16          762,087.69
#
#        DIV_02_DIRECT_COST  DIV_03_DIRECT_COST  DIV_04_DIRECT_COST  \
# count            3,332.00            3,332.00            3,332.00
# mean           120,305.74          305,087.19           25,975.15
# std            835,518.53        2,456,075.21          255,679.11
# min            -41,282.56       -4,315,458.20         -164,664.12
# 25%                  0.00                0.00                0.00
# 50%                889.22                0.00                0.00
# 75%             10,486.36            1,041.34                0.00
# max         26,715,320.64       49,560,386.64        9,635,075.36
#
#        DIV_05_DIRECT_COST  DIV_06_DIRECT_COST  DIV_07_DIRECT_COST  \
# count            3,332.00            3,332.00            3,332.00
# mean           192,784.27           83,875.74           97,562.86
# std          1,926,522.10          479,208.15          712,596.43
# min         -1,398,362.17         -174,550.72          -16,197.24
# 25%                  0.00                0.00                0.00
# 50%                  0.00              353.55                0.00
# 75%                180.50           10,992.53               44.95
# max         51,850,542.49        9,711,287.61       19,337,427.69
#
#        DIV_08_DIRECT_COST  ...  DIV_26_DIRECT_COST  DIV_27_DIRECT_COST  \
# count            3,332.00  ...            3,332.00            3,332.00
# mean           262,156.35  ...          279,623.43           22,192.54
# std          2,347,850.24  ...        2,283,423.57          355,302.65
# min           -407,656.41  ...             -104.77                0.00
# 25%                  0.00  ...                0.00                0.00
# 50%                 37.68  ...                0.00                0.00
# 75%              9,230.26  ...            3,893.87                0.00
# max         56,887,683.67  ...       57,604,860.12       14,904,687.98
#
#        DIV_28_DIRECT_COST  DIV_31_DIRECT_COST  DIV_32_DIRECT_COST  \
# count            3,332.00            3,332.00            3,332.00
# mean             7,159.77           84,671.51           18,546.22
# std             98,050.42          852,341.42          200,217.24
# min                  0.00           -2,322.10              -11.50
# 25%                  0.00                0.00                0.00
# 50%                  0.00                0.00                0.00
# 75%                  0.00                0.00                0.00
# max          2,706,150.04       19,786,153.90        6,898,015.60
#
#        DIV_33_DIRECT_COST  DIV_34_DIRECT_COST  DIV_55_DIRECT_COST  \
# count            3,332.00            3,332.00            3,332.00
# mean            19,750.99              505.83            1,710.05
# std            315,920.99           14,397.44           98,425.42
# min            -53,330.53               -4.20                0.00
# 25%                  0.00                0.00                0.00
# 50%                  0.00                0.00                0.00
# 75%                  0.00                0.00                0.00
# max         10,785,799.69          607,500.00        5,681,453.04
#
#            GCS_COST      GRS_COST
# count      3,332.00      3,332.00
# mean     159,975.26    130,762.61
# std      991,159.86    893,014.97
# min   -3,335,087.00   -629,785.00
# 25%          554.25        305.75
# 50%        4,763.00      2,099.00
# 75%       35,369.50     16,783.00
# max   23,749,853.00 18,182,714.00
#
# [8 rows x 34 columns]

# %%
X  = df_working.iloc[:,:-2] #.values
y_gcs = df_working.iloc[:,-2:-1].values.ravel()
y_grs = df_working.iloc[:,-1:].values.ravel()
y_grs.shape
# Out:
# (3332,)

# %% [markdown]
# In the last itteration, I got everything I was trying to do to work. that is, I trained a model and saved it as a binary object that can be packaged with an app, and tested the implementation within the app framework.
# that part all works great! it's super fast, and I think we'll be able to get the ui pretty nice at the end.
# the thing to be aware of at this point is that it can't be expected to be reliable. yet
# here's what I think are next steps in order to make it as reliable as possible, and to be able to know exactly how reliable it is. this is what I'll do in this itteration:
# 1.  identify metrics by which model success will be measured. e.g., MSE, RMSE, MAE, MAPE
# 2.  implement train / test split prior to cross validation
# 3.  rerun the cross validation setup for this estimator (knearestneighborsregressor) with the training data only
# 4.  evaluate, in terms of our selected metrics, the model selected by cross validation against the test data (to which it would be naïve at this point. this will guard us against data leakage)
# 5.  repeat steps 3 and 4 for a few other estimators. I'm thinking lasso, elasticnet, maybe ridgeregression or svr, and perhaps mlpregressor if we're feeling ambitious
# compare the scores of our models and pick the best one
#
# initially, trying these scorers: r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, mean_absolute_percentage_error, median_absolute_error, max_error

# %%
X_train, X_test, y_grs_train, y_grs_test = train_test_split(X, y_grs, test_size=0.33, random_state=42)
X_train, X_test, y_gcs_train, y_gcs_test = train_test_split(X, y_gcs, test_size=0.33, random_state=42)

# %%
def print_dataframe(filtered_cv_results):
    """Pretty print for filtered dataframe"""
    for mean_r2, std_r2, mean_negmedae, std_negmedae, params in zip(
        filtered_cv_results["mean_test_R2"],
        filtered_cv_results["std_test_R2"],
        filtered_cv_results["mean_test_negMedAE"],
        filtered_cv_results["std_test_negMedAE"],
        filtered_cv_results["params"],
    ):
        print(
            f"R2: {mean_r2:0.3f} (±{std_r2:0.03f}),"
            f" negMedAE: {mean_negmedae:0.3f} (±{std_negmedae:0.03f}),"
            f" for {params}"
        )
    print()

def refit_strategy(cv_results):
    """Define the strategy to select the best estimator.

    The strategy defined here is to filter-out all results below a R2 threshold
    of 0.5, rank the remaining by MedAE and keep all models with one standard
    deviation of the best by MedAE. Once these models are selected, we can select the
    fastest model to predict.

    Parameters
    ----------
    cv_results : dict of numpy (masked) ndarrays
        CV results as returned by the `GridSearchCV`.

    Returns
    -------
    best_index : int
        The index of the best estimator as it appears in `cv_results`.
    """
    # print the info about the grid-search for the different scores
    r2_threshold = 0.67

    cv_results_ = pd.DataFrame(cv_results)
    print("All grid-search results:")
    print_dataframe(cv_results_)

    # Filter-out all results below the threshold
    high_r2_cv_results = cv_results_[
        cv_results_["mean_test_R2"] > r2_threshold
    ]

    print(f"Models with an R2 higher than {r2_threshold}:")
    print_dataframe(high_r2_cv_results)

    high_r2_cv_results = high_r2_cv_results[
        [
            "mean_score_time",
            "mean_test_R2",
            "std_test_R2",
            "mean_test_negMedAE",
            "std_test_negMedAE",
            "rank_test_R2",
            "rank_test_negMedAE",
            "params",
        ]
    ]

    # Select the most performant models in terms of negMedAE
    # (within 1 sigma from the best)
    best_negmedae_std = high_r2_cv_results["mean_test_negMedAE"].std()
    best_negmedae = high_r2_cv_results["mean_test_negMedAE"].max()
    best_negmedae_threshold = best_negmedae - best_negmedae_std

    high_negmedae_cv_results = high_r2_cv_results[
        high_r2_cv_results["mean_test_negMedAE"] > best_negmedae_threshold
    ]
    print(
        "Out of the previously selected high R2 models, we keep all the\n"
        "the models within one standard deviation of the highest negMedAE model:"
    )
    print_dataframe(high_negmedae_cv_results)

    # From the best candidates, select the fastest model to predict
    fastest_top_negmedae_high_r2_index = high_negmedae_cv_results[
        "mean_score_time"
    ].idxmin()

    print(
        "\nThe selected final model is the fastest to predict out of the previously\n"
        "selected subset of best models based on R2 and negMedAE.\n"
        "Its scoring time is:\n\n"
        f"{high_negmedae_cv_results.loc[fastest_top_negmedae_high_r2_index]}"
    )

    return fastest_top_negmedae_high_r2_index

# %%
# make a custom scorer
def neg_median_absolute_error(y_true, y_pred):
    medae = median_absolute_error(y_true, y_pred)
    return -medae

# pipeline setup
pipeline = Pipeline([
                     ('scaler', None)            #start with no scaler. scalers account for differences in scale between features
                    # ,('kbest', SelectKBest(f_classif))     #select k best indy vars where k = winning parameter below
                     ,('regressor', ElasticNet())                #the estimator, aka the ai
                     ])

parameters = {
                'scaler':  [RobustScaler(), Normalizer(), QuantileTransformer()]   #try all these scalers
                # ,'kbest__k':  list(range(1, X.shape[1]+1))                         #with all these numbers of best indy vars (between 1 and the number of vars)
                ,'regressor__alpha':np.arange(100, 150, 5)                     #try various alpha settings
                ,'regressor__l1_ratio':np.arange(0.2, 1.0, 0.1)                #try various alpha settings
                ,'regressor__fit_intercept':[True, False]                      #try various fit_intercept settings
                ,'regressor__selection':['cyclic', 'random']                   #try various selection settings
                }
#grs model
grs_grid = GridSearchCV(
    pipeline
    ,parameters
    ,cv=10
    ,scoring={'R2': make_scorer(r2_score)
            ,'negMedAE': make_scorer(neg_median_absolute_error)
    }
    # ,refit='R2'
    ,refit=refit_strategy
    ,return_train_score=False
    ,n_jobs=-1
)   

#gcs model
gcs_grid = GridSearchCV(
    pipeline
    ,parameters
    ,cv=10
    ,scoring={'R2': make_scorer(r2_score)
            ,'negMedAE': make_scorer(neg_median_absolute_error)
    }
    ,refit=refit_strategy
    ,return_train_score=False
    ,n_jobs=-1
)

# %%
np.arange(100, 150, 5)
# Out:
# array([100, 105, 110, 115, 120, 125, 130, 135, 140, 145])

# %%
grs_grid = grs_grid.fit(X_train, y_grs_train)
# Out:
# All grid-search results:
# R2: 0.700 (±0.200), negMedAE: -14348.124 (±1547.992), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129719.623 (±4969.567), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.015 (±0.047), negMedAE: -128658.778 (±4927.870), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.700 (±0.200), negMedAE: -14348.156 (±1548.028), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129719.623 (±4969.567), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.015 (±0.047), negMedAE: -128658.777 (±4927.869), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.700 (±0.200), negMedAE: -14319.723 (±1558.918), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129717.349 (±4970.499), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.015 (±0.046), negMedAE: -128427.610 (±4937.867), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.700 (±0.200), negMedAE: -14319.722 (±1558.918), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129717.349 (±4970.498), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.015 (±0.046), negMedAE: -128427.620 (±4937.895), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.700 (±0.200), negMedAE: -14283.452 (±1586.431), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129715.209 (±4971.481), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.014 (±0.046), negMedAE: -128143.947 (±4927.632), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.700 (±0.200), negMedAE: -14283.449 (±1586.433), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129715.209 (±4971.481), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.014 (±0.046), negMedAE: -128143.938 (±4927.631), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.699 (±0.200), negMedAE: -14247.682 (±1601.479), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129714.502 (±4973.800), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.013 (±0.045), negMedAE: -127748.852 (±4890.699), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.699 (±0.200), negMedAE: -14247.686 (±1601.473), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.018 (±0.050), negMedAE: -129714.502 (±4973.800), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.013 (±0.045), negMedAE: -127748.826 (±4890.695), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.699 (±0.201), negMedAE: -
for {'regressor__alpha': 140, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.697 (±0.203), negMedAE: -2710.431 (±698.954), for {'regressor__alpha': 140, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.696 (±0.203), negMedAE: -2752.332 (±706.711), for {'regressor__alpha': 140, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.696 (±0.203), negMedAE: -2752.562 (±696.953), for {'regressor__alpha': 140, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.699 (±0.202), negMedAE: -2677.621 (±616.064), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.699 (±0.202), negMedAE: -2677.621 (±616.064), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.699 (±0.202), negMedAE: -2702.609 (±631.917), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.699 (±0.202), negMedAE: -2702.610 (±631.917), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.698 (±0.202), negMedAE: -2698.273 (±629.259), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.698 (±0.202), negMedAE: -2698.278 (±629.259), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.698 (±0.202), negMedAE: -2691.924 (±631.310), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.698 (±0.202), negMedAE: -2691.925 (±631.310), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.698 (±0.202), negMedAE: -2691.981 (±645.947), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.698 (±0.202), negMedAE: -2691.983 (±645.947), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.697 (±0.202), negMedAE: -2710.797 (±662.890), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.697 (±0.202), negMedAE: -2710.797 (±662.891), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.697 (±0.203), negMedAE: -2706.070 (±696.269), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.697 (±0.203), negMedAE: -2705.811 (±696.312), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: 0.696 (±0.203), negMedAE: -2750.618 (±705.857), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: 0.696 (±0.203), negMedAE: -2749.216 (±707.254), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
#
#
# The selected final model is the fastest to predict out of the previously
# selected subset of best models based on R2 and negMedAE.
# Its scoring time is:
#
# mean_score_time                                                    0.00
# mean_test_R2                                                       0.70
# std_test_R2                                                        0.20
# mean_test_negMedAE                                            -2,758.26
# std_test_negMedAE                                                702.86
# rank_test_R2                                                        316
# rank_test_negMedAE                                                  267
# params                {'regressor__alpha': 120, 'regressor__fit_inte...
# Name: 477, dtype: object
# c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.014e+14, tolerance: 2.037e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
gcs_grid = gcs_grid.fit(X_train, y_gcs_train) #fails to converge, therefore knnr is superior
# Out:
# All grid-search results:
# R2: 0.517 (±0.461), negMedAE: -34721.796 (±4552.366), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153030.420 (±4987.462), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.008 (±0.025), negMedAE: -151919.215 (±4839.549), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.517 (±0.461), negMedAE: -34721.800 (±4552.365), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153030.420 (±4987.461), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.008 (±0.025), negMedAE: -151919.208 (±4839.554), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.2, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.515 (±0.463), negMedAE: -34623.822 (±4553.030), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153031.620 (±4985.919), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.007 (±0.024), negMedAE: -151785.746 (±4821.724), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.515 (±0.463), negMedAE: -34623.829 (±4553.028), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153031.620 (±4985.919), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.007 (±0.024), negMedAE: -151785.732 (±4821.712), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.30000000000000004, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.514 (±0.466), negMedAE: -34532.154 (±4561.547), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153034.895 (±4983.061), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.007 (±0.024), negMedAE: -151575.988 (±4804.270), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.514 (±0.466), negMedAE: -34532.158 (±4561.546), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153034.895 (±4983.061), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.007 (±0.024), negMedAE: -151575.983 (±4804.272), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.4000000000000001, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.512 (±0.469), negMedAE: -34429.021 (±4563.794), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153032.733 (±4977.901), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.006 (±0.024), negMedAE: -151279.623 (±4760.280), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.512 (±0.469), negMedAE: -34429.023 (±4563.795), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153032.735 (±4977.898), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.006 (±0.024), negMedAE: -151279.609 (±4760.269), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.5000000000000001, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.510 (±0.472), negMedAE: -34313.576 (±4560.511), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153025.250 (±4968.587), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.005 (±0.023), negMedAE: -150701.853 (±4766.431), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.510 (±0.472), negMedAE: -34313.596 (±4560.516), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153025.249 (±4968.587), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.005 (±0.023), negMedAE: -150701.809 (±4766.360), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.508 (±0.476), negMedAE: -34206.083 (±4572.703), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153025.260 (±4955.766), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.003 (±0.022), negMedAE: -149737.177 (±4710.050), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.508 (±0.476), negMedAE: -34206.083 (±4572.692), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -153025.263 (±4955.768), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.003 (±0.022), negMedAE: -149737.176 (±4710.053), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.505 (±0.480), negMedAE: -34122.925 (±4579.583), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -152981.899 (±4963.191), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: 0.001 (±0.020), negMedAE: -147700.085 (±4621.571), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.505 (±0.480), negMedAE: -34122.793 (±4579.482), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.011 (±0.027), negMedAE: -152981.894 (±4963.193), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: 0.001 (±0.020), negMedAE: -147699.918 (±4621.384), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.502 (±0.485), negMedAE: -34015.174 (±4591.722), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.010 (±0.026), negMedAE: -152835.735 (±4925.920), for {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: 0
for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.035 (±0.019), negMedAE: -3317.964 (±1188.350), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.018 (±0.011), negMedAE: -15483.115 (±782.386), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.6000000000000001, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.509 (±0.475), negMedAE: -4002.481 (±1025.518), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.035 (±0.019), negMedAE: -3225.142 (±784.931), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.013 (±0.011), negMedAE: -20200.514 (±1078.265), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.509 (±0.475), negMedAE: -4002.498 (±1025.516), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.035 (±0.019), negMedAE: -3225.142 (±784.930), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.013 (±0.011), negMedAE: -20200.529 (±1078.267), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.7000000000000002, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.506 (±0.480), negMedAE: -4030.853 (±1006.577), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.034 (±0.018), negMedAE: -4066.412 (±189.047), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: -0.004 (±0.013), negMedAE: -28802.648 (±1532.320), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.506 (±0.480), negMedAE: -4030.872 (±1006.712), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.034 (±0.018), negMedAE: -4066.417 (±189.047), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: -0.004 (±0.013), negMedAE: -28802.699 (±1532.308), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.8000000000000003, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
# R2: 0.501 (±0.487), negMedAE: -4005.851 (±1006.916), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'cyclic', 'scaler': RobustScaler()}
# R2: -0.031 (±0.017), negMedAE: -7496.903 (±234.358), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'cyclic', 'scaler': Normalizer()}
# R2: 0.015 (±0.023), negMedAE: -50171.432 (±2745.386), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'cyclic', 'scaler': QuantileTransformer()}
# R2: 0.501 (±0.487), negMedAE: -4007.877 (±1005.475), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'random', 'scaler': RobustScaler()}
# R2: -0.031 (±0.017), negMedAE: -7496.903 (±234.360), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'random', 'scaler': Normalizer()}
# R2: 0.015 (±0.023), negMedAE: -50172.200 (±2746.018), for {'regressor__alpha': 145, 'regressor__fit_intercept': False, 'regressor__l1_ratio': 0.9000000000000001, 'regressor__selection': 'random', 'scaler': QuantileTransformer()}
#
# Models with an R2 higher than 0.67:
#
# Out of the previously selected high R2 models, we keep all the
# the models within one standard deviation of the highest negMedAE model:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\SwanS\projects\streamlit_ml_grs_fit\elasticnet_grs_fit_model_training.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> gcs_grid = gcs_grid.fit(X_train, y_gcs_train) #fails to converge, therefore knnr is superior
#
# File c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\sklearn\model_selection\_search.py:914, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     910 # For multi-metric evaluation, store the best_index_, best_params_ and
#     911 # best_score_ iff refit is one of the scorer names
#     912 # In single metric evaluation, refit_metric is "score"
#     913 if self.refit or not self.multimetric_:
# --> 914     self.best_index_ = self._select_best_index(
#     915         self.refit, refit_metric, results
#     916     )
#     917     if not callable(self.refit):
#     918         # With a non-custom callable, we can select the best score
#     919         # based on the best index
#     920         self.best_score_ = results[f"mean_test_{refit_metric}"][
#     921             self.best_index_
#     922         ]
#
# File c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\sklearn\model_selection\_search.py:748, in BaseSearchCV._select_best_index(refit, refit_metric, results)
#     744 """Select index of the best combination of hyperparemeters."""
#     745 if callable(refit):
#     746     # If callable, refit is expected to return the index of the best
#     747     # parameter set.
# --> 748     best_index = refit(results)
#     749     if not isinstance(best_index, numbers.Integral):
#     750         raise TypeError("best_index_ returned is not an integer")
#
# c:\Users\SwanS\projects\streamlit_ml_grs_fit\elasticnet_grs_fit_model_training.ipynb Cell 11 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=75'>76</a> print_dataframe(high_negmedae_cv_results)
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=77'>78</a> # From the best candidates, select the fastest model to predict
# ---> <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=78'>79</a> fastest_top_negmedae_high_r2_index = high_negmedae_cv_results[
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=79'>80</a>     "mean_score_time"
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=80'>81</a> ].idxmin()
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=82'>83</a> print(
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=83'>84</a>     "\nThe selected final model is the fastest to predict out of the previously\n"
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=84'>85</a>     "selected subset of best models based on R2 and negMedAE.\n"
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=85'>86</a>     "Its scoring time is:\n\n"
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=86'>87</a>     f"{high_negmedae_cv_results.loc[fastest_top_negmedae_high_r2_index]}"
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=87'>88</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/SwanS/projects/streamlit_ml_grs_fit/elasticnet_grs_fit_model_training.ipynb#X12sZmlsZQ%3D%3D?line=89'>90</a> return fastest_top_negmedae_high_r2_index
#
# File c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\pandas\core\series.py:2495, in Series.idxmin(self, axis, skipna, *args, **kwargs)
#    2432 def idxmin(self, axis: Axis = 0, skipna: bool = True, *args, **kwargs) -> Hashable:
#    2433     """
#    2434     Return the row label of the minimum value.
#    2435
#    (...)
#    2493     nan
#    2494     """
# -> 2495     i = self.argmin(axis, skipna, *args, **kwargs)
#    2496     if i == -1:
#    2497         return np.nan
#
# File c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\pandas\core\base.py:717, in IndexOpsMixin.argmin(self, axis, skipna, *args, **kwargs)
#     713         return delegate.argmin()
#     714 else:
#     715     # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     716     # "int")
# --> 717     return nanops.nanargmin(  # type: ignore[return-value]
#     718         delegate, skipna=skipna
#     719     )
#
# File c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File c:\Users\SwanS\Anaconda3\envs\grs_fit\lib\site-packages\pandas\core\nanops.py:1150, in nanargmin(values, axis, skipna, mask)
#    1148 values, mask, _, _, _ = _get_values(values, True, fill_value_typ="+inf", mask=mask)
#    1149 # error: Need type annotation for 'result'
# -> 1150 result = values.argmin(axis)  # type: ignore[var-annotated]
#    1151 result = _maybe_arg_null_out(result, axis, mask, skipna)
#    1152 return result
#
# ValueError: attempt to get argmin of an empty sequence

# %%
y_grs_test_pred = grs_grid.best_estimator_.predict(X_test)
print(f'R2 for test grs data: {r2_score(y_grs_test, y_grs_test_pred)}')
print(f'negMedAE for test grs data: {neg_median_absolute_error(y_grs_test, y_grs_test_pred)}')

# %%
y_gcs_test_pred = gcs_grid.best_estimator_.predict(X_test)
print(f'R2 for test gcs data: {r2_score(y_gcs_test, y_gcs_test_pred)}')
print(f'negMedAE for test gcs data: {neg_median_absolute_error(y_gcs_test, y_gcs_test_pred)}')

# %%
gcs_grid_test = gcs_grid.best_estimator_.fit(X_test, y_gcs_test)

# %%
print("the best grs estimator is \n {} ".format(grs_grid.best_estimator_))
print("the best grs parameters are \n {}".format(grs_grid.best_params_))
print("the best gcs estimator is \n {} ".format(gcs_grid.best_estimator_))
print("the best gcs parameters are \n {}".format(gcs_grid.best_params_))

# %%
grs_best_pipe = grs_grid.best_estimator_
grs_mask = list(grs_best_pipe.fit(X,y_grs)[:-1].get_feature_names_out())
grs_model = grs_best_pipe.fit(df_working[grs_mask],y_grs)
grs_predictions = grs_model.predict(df_working[grs_mask])

# %%
gcs_best_pipe = gcs_grid.best_estimator_
gcs_mask = list(gcs_best_pipe.fit(X,y_gcs)[:-1].get_feature_names_out())
gcs_model = gcs_best_pipe.fit(df_working[gcs_mask],y_gcs)
gcs_predictions = gcs_model.predict(df_working[gcs_mask])

# %%
list(grs_model[:-1].get_feature_names_out())

# %%
grs_parameters = list(df_working[grs_mask].columns)
gcs_parameters = list(df_working[gcs_mask].columns)
combined_mask = list(set(grs_parameters + gcs_parameters))
df = df_working[combined_mask].copy()
df['GRS_PREDICTIONS'] = grs_predictions
df['GCS_PREDICTIONS'] = gcs_predictions
knnr_model_bag = {
    'df': df
    ,'grs_model': grs_model
    ,'grs_parameters': grs_parameters
    ,'gcs_model': gcs_model
    ,'gcs_parameters': gcs_parameters
}
with open('./app/knnr_model_bag.pkl','wb') as p:
    pickle.dump(knnr_model_bag, p, protocol=-1)

# %%
with open('./app/knnr_model_bag.pkl','rb') as p:
    bag = pickle.load(p)

# %%
bag.keys()

# %%
grs_params = bag['grs_parameters']
gcs_params = bag['gcs_parameters']
all_params = list(set(grs_params + gcs_params))
test_vec = bag['df'][all_params].sample(1).copy()
# bag['grs_model'].predict(test_vec)
# model = bag['grs_model']
# list(model[:-1].get_feature_names_out())
# print(*list(test_vec[grs_params].columns), sep='\n,')
gcs_params

# %%
vec = test_vec.reset_index(drop=True).T
vec.index.names = ['PARAMETERS']
vec = vec.reset_index()
vec.set_index('PARAMETERS').sort_index()

# %%
bag['grs_model'].predict(test_vec)

# %%
# get the features scores rounded in 2 decimals
pip_steps = grs_grid.best_estimator_.named_steps['kbest']
pip_steps.get_support()

features_scores = ['%.2f' % elem for elem in pip_steps.scores_ ]
print("the features scores are \n {}".format(features_scores))

feature_scores_pvalues = ['%.3f' % elem for elem in pip_steps.pvalues_]
print("the feature_pvalues is \n {} ".format(feature_scores_pvalues))

scored_features = pd.DataFrame(df_working[grs_mask].columns, columns=['feature_names'])
scored_features['feature_scores'] = features_scores
scored_features['feature_scores_pvalues'] = feature_scores_pvalues
scored_features = scored_features.loc[(scored_features['feature_scores'] != 'nan') & (scored_features['feature_scores'] != 'inf')].sort_values(by='feature_scores', ascending=False).iloc[:num_features]
scored_features

# %%
selected_features = scored_features.feature_names.to_list()
df_working[selected_features].describe()

# %%
pickle.dump(neigh, open('grs_model.pkl','wb'))

# %%
grs_model = pickle.load(open('grs_model.pkl','rb'))

# %%
pickle.dump(data_preds, open('grs_model.pkl','ab+'))

# %%
grs_data = []
with open('./app/grs_model.pkl', 'rb') as fr:
    try:
        while True:
            grs_data.append(pickle.load(fr))
    except EOFError:
        pass
gcs_data = []
with open('./app/gcs_model.pkl', 'rb') as fr:
    try:
        while True:
            gcs_data.append(pickle.load(fr))
    except EOFError:
        pass

# %%
grs_model, grs_preds = grs_data
gcs_model, gcs_preds = gcs_data

# %%
graphWidth = 1500
graphHeight = graphWidth * 800 / 1000
x_plot = data_preds.DIRECT_COST
y1_plot = data_preds.GRS_ACTUAL
y2_plot = data_preds.GRS_PREDICTIONS
f = plt.figure(figsize=(graphWidth/100.0, graphHeight/100.0), dpi=100)
axes = f.add_subplot(111)
axes.plot(x_plot, y1_plot, c='g', alpha=0.15)
axes.plot(x_plot, y2_plot, alpha=0.15)
axes.scatter(direct_cost, grs_cost, c='r', marker='D')
plt.show()
